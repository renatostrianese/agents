# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')
openai_endpoint = os.getenv('OPENAI_API_ENDPOINT')
openai_model = os.getenv('OPENAI_MODEL')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

if openai_endpoint:
    print(f"OpenAI Endpoint exists and begins {openai_endpoint}")
else:
    print("OpenAI Endpoint not set - please head to the troubleshooting guide in the setup folder")

if openai_model:
    print(f"OpenAI Model exists and begins {openai_model}")
else:
    print("OpenAI Model not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins E2c7izuB
# OpenAI Endpoint exists and begins https://aaif-demo-rsv.cognitiveservices.azure.com/
# OpenAI Model exists and begins gpt-4.1-rsv

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import AzureOpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = AzureOpenAI(
    azure_endpoint=openai_endpoint,
    api_key=openai_api_key,
    api_version="2025-01-01-preview"
)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A clock is set correctly at 12 noon. It loses 15 minutes every 24 hours. What will be the true time when it shows 12 noon after 30 days?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# **Given:**
# - The clock is correct at 12 noon initially.
# - It **loses 15 minutes every 24 hours**.
# - We need to find the **true time when the faulty clock shows 12:00 noon after 30 days**.
#
# ---
#
# ## Step 1: Calculate Total Loss in 30 Days
#
# - Loss per day = **15 minutes**
# - In 30 days, total loss = \( 15 \text{ minutes} \times 30 = 450 \) minutes
#
# \( 450 \) minutes = \( 7 \) hours and \( 30 \) minutes.
#
# ---
#
# ## Step 2: Understand What This Means
#
# After **30 days** (by actual/truthful time), the faulty clock is behind by **7 hours 30 minutes**.
#
# But, per the **clock**, when it shows 12:00, the **actual time is ahead** by that amount.
#
# ---
#
# ## Step 3: Find When It Shows 12:00 (on the faulty clock)
#
# Let the **actual elapsed time** be \( T \) (in hours), and the **clock's elapsed time** be \( t \).
#
# In 24 hours of actual time, the clock moves **15 minutes (0.25 hour) slow**, so:
#
# In **24 actual hours**, clock moves **23 hours 45 minutes**.
#
# So, in \( T \) actual hours,
#
# \[
# \text{Clock's time} = T \times \frac{23.75}{24}
# \]
#
# Originally, 12:00 noon at both clocks, so let’s see when the **clock shows 30 days (720 hours)**.
#
# Set up the equation:
#
# \[
# \text{Clock's hours shown} = T \times \frac{23.75}{24} = 30 \text{ days} = 720 \text{ hours}
# \]
#
# So,
#
# \[
# T = \frac{720 \times 24}{23.75}
# \]
# \[
# T = \frac{17280}{23.75}
# \]
# \[
# T = 727.3684 \text{ hours}
# \]
#
# ---
#
# ## Step 4: Find How Much True Time Has Passed
#
# From **noon on day 1** (+727.3684 hours) is when the faulty clock will show 12:00 after "30 days" on its own dial.
#
# Calculate \( 727.3684 \) hours in days and hours:
#
# \[
# 727.3684 \div 24 = 30.30702 \text{ days}
# \]
#
# So,
#
# - \( 0.30702 \times 24 = 7.3684 \) hours
# - \( 0.3684 \times 60 \approx 22 \) minutes
#
# So,
#
# - The actual time passed: **30 days, 7 hours, and 22 minutes (approx)**
#
# ---
#
# ## Step 5: What's the **True Time** When The Faulty Clock Shows 12:00?
#
# If it originally started at **12:00 noon**, **add 30 days, 7 hours, 22 minutes** to it:
#
# \[ \boxed{12:00 \text{ noon } + 30 \text{ days},\ 7\ \text{hours},\ 22\ \text{minutes}} \]
#
# So,
#
# **True time is**:
# \[
# \boxed{7:22\ \mathrm{p.m.}\ \text{on the 31st day}}
# \]
#
# Or, more formally:
#
# \[
# \boxed{\text{On the }31^\text{st} \text{ day, at 7:22 PM, the true time, when the faulty clock shows 12:00 noon after 30 days}}
# \]
#
# ---
#
# ### **Summary Table**
#
# | Faulty Clock Shows | True Time Elapsed       | Date/Time (from original start)     |
# |:------------------:|:----------------------:|:-----------------------------------:|
# | 12:00 noon (start) | 0 days 0 hours         | 12:00 noon, day 1                   |
# | 12:00 noon (after 30 "clock" days) | 30 days, 7 hours, 22 minutes | 7:22 PM, day 31                    |
#
# **Final Answer:**
#
# \[
# \boxed{7:22\ \mathrm{PM}\ \text{on the 31st day (i.e., 30 days, 7 hours, 22 minutes after start)}}
# \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# **Given:**
# - The clock is correct at 12 noon initially.
# - It **loses 15 minutes every 24 hours**.
# - We need to find the **true time when the faulty clock shows 12:00 noon after 30 days**.
#
# ---
#
# ## Step 1: Calculate Total Loss in 30 Days
#
# - Loss per day = **15 minutes**
# - In 30 days, total loss = \( 15 \text{ minutes} \times 30 = 450 \) minutes
#
# \( 450 \) minutes = \( 7 \) hours and \( 30 \) minutes.
#
# ---
#
# ## Step 2: Understand What This Means
#
# After **30 days** (by actual/truthful time), the faulty clock is behind by **7 hours 30 minutes**.
#
# But, per the **clock**, when it shows 12:00, the **actual time is ahead** by that amount.
#
# ---
#
# ## Step 3: Find When It Shows 12:00 (on the faulty clock)
#
# Let the **actual elapsed time** be \( T \) (in hours), and the **clock's elapsed time** be \( t \).
#
# In 24 hours of actual time, the clock moves **15 minutes (0.25 hour) slow**, so:
#
# In **24 actual hours**, clock moves **23 hours 45 minutes**.
#
# So, in \( T \) actual hours,
#
# \[
# \text{Clock's time} = T \times \frac{23.75}{24}
# \]
#
# Originally, 12:00 noon at both clocks, so let’s see when the **clock shows 30 days (720 hours)**.
#
# Set up the equation:
#
# \[
# \text{Clock's hours shown} = T \times \frac{23.75}{24} = 30 \text{ days} = 720 \text{ hours}
# \]
#
# So,
#
# \[
# T = \frac{720 \times 24}{23.75}
# \]
# \[
# T = \frac{17280}{23.75}
# \]
# \[
# T = 727.3684 \text{ hours}
# \]
#
# ---
#
# ## Step 4: Find How Much True Time Has Passed
#
# From **noon on day 1** (+727.3684 hours) is when the faulty clock will show 12:00 after "30 days" on its own dial.
#
# Calculate \( 727.3684 \) hours in days and hours:
#
# \[
# 727.3684 \div 24 = 30.30702 \text{ days}
# \]
#
# So,
#
# - \( 0.30702 \times 24 = 7.3684 \) hours
# - \( 0.3684 \times 60 \approx 22 \) minutes
#
# So,
#
# - The actual time passed: **30 days, 7 hours, and 22 minutes (approx)**
#
# ---
#
# ## Step 5: What's the **True Time** When The Faulty Clock Shows 12:00?
#
# If it originally started at **12:00 noon**, **add 30 days, 7 hours, 22 minutes** to it:
#
# \[ \boxed{12:00 \text{ noon } + 30 \text{ days},\ 7\ \text{hours},\ 22\ \text{minutes}} \]
#
# So,
#
# **True time is**:
# \[
# \boxed{7:22\ \mathrm{p.m.}\ \text{on the 31st day}}
# \]
#
# Or, more formally:
#
# \[
# \boxed{\text{On the }31^\text{st} \text{ day, at 7:22 PM, the true time, when the faulty clock shows 12:00 noon after 30 days}}
# \]
#
# ---
#
# ### **Summary Table**
#
# | Faulty Clock Shows | True Time Elapsed       | Date/Time (from original start)     |
# |:------------------:|:----------------------:|:-----------------------------------:|
# | 12:00 noon (start) | 0 days 0 hours         | 12:00 noon, day 1                   |
# | 12:00 noon (after 30 "clock" days) | 30 days, 7 hours, 22 minutes | 7:22 PM, day 31                    |
#
# **Final Answer:**
#
# \[
# \boxed{7:22\ \mathrm{PM}\ \text{on the 31st day (i.e., 30 days, 7 hours, 22 minutes after start)}}
# \]

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Por favor elige una industria que sea interesante explorar para aplicar AI con agentes"}]

# Then make the first call:

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

messages = [{"role": "user", "content": f"Cual es un problema en la industria de {business_idea} que podria ser abordado con AI y agentes?"}]

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

problem = response.choices[0].message.content

messages = [{"role": "user", "content": f"Como podria un agent de AI abordar el problema de {problem} en la industria de {business_idea}?"}]

response = openai.chat.completions.create(
    model=openai_model,
    messages=messages
)

solution = response.choices[0].message.content

display(Markdown(solution))
# Out:
# ¡Excelente análisis! Permíteme abordar **cómo un agente de IA podría atacar este problema**, formalizándolo como un **caso de uso detallado** en la industria de logística/cadena de suministro, usando el paradigma de agentes. Así, podrás visualizar un **roadmap** para una implementación real.
#
# ---
#
# ## Caso de Uso Formal: Coordinación Resiliente en la Cadena Logística con Multi-Agentes AI
#
# ### 1. **Definición del Problema**
# En una red logística global, eventos imprevistos (accidentes, clima, retrasos de proveedores, cambios regulatorios) interrumpen el flujo de bienes, generando pérdidas y afectando el servicio al cliente. El reto es **detectar, comunicar y replanificar** estas disrupciones en tiempo real, con mínima intervención humana.
#
# ---
#
# ### 2. **Arquitectura de Solución con Agentes AI**
#
# #### **Actores representados por agentes**
# - **Agente de almacén:** Supervisa inventario/salida/recepción.
# - **Agente de vehículo/transporte:** Supervisa ubicación/ruta/capacidad/estado.
# - **Agente de ruta:** Monitoreo de tráfico/clima/cierres.
# - **Agente de proveedor:** Estado y tiempos de entrega de materia prima.
# - **Agente de pedido/cliente:** Supervisa estado de sus órdenes.
# - **Agente negociador:** Propone alternativas ante disrupciones.
#
# #### **Capacidades**
# - **Percepción:** Cada agente recibe datos locales y contextuales (sensores IoT, APIs de tráfico, sistema ERP).
# - **Comunicación:** Los agentes comparten cambios y negocian en tiempo real (protocolos multi-agente tipo FIPA, mensajes estándar).
# - **Toma de decisiones local + colaborativa:** Cada agente busca optimizar su contexto, pero cooperando hacia métricas globales (puntualidad, costo, mínimas disrupciones).
# - **Replanificación automática:** Al detectar una alteración (ej. puente caído), los agentes colaboran para reasignar rutas, ajustar horarios, notificar cambios.
#
# ---
#
# ### 3. **Flujo de trabajo ante una interrupción**
#
# 1. **Detección:**
#    - Agente de ruta recibe información de cierre vial por accidente (API de tráfico, sensor IoT).
# 2. **Comunicación inmediata:**
#    - Informa a los agentes de transporte y almacén involucrados.
# 3. **Simulación rápida de alternativas:**
#    - Agentes de transporte consultan rutas alternativas y calculan demoras.
#    - Si ninguna es aceptable, el agente negociador busca opciones (recurrir a otro medio, reprogramar entregas parciales, tercerizar transporte).
# 4. **Replanificación colaborativa:**
#    - Se elabora un nuevo plan logístico: almacenes ajustan ventanas de carga, clientes reciben notificación automática de demora.
#    - El sistema sigue iterando si surgen nuevas restricciones.
# 5. **Aprendizaje y mejora:**
#    - El incidente se registra; el sistema aprende de sus decisiones (machine learning/reinforcement learning), optimizando futuras respuestas.
#
# ---
#
# ### 4. **Beneficios Directos**
#
# - **Respuesta en minutos/segundos** vs. horas en gestión manual.
# - **Mitigación activa de impacto:** menos pérdidas de mercancía y penalizaciones.
# - **Información clara y oportuna para todos los afectados** (visión “end-to-end”).
# - **Escalabilidad:** agregar más agentes conforme crece tu red logística.
# - **Feedback auto-mejorado:** optimización constante por historial de incidencias.
#
# ---
#
# ### 5. **Componentes tecnológicos clave**
#
# - **Plataforma multi-agente** (ej: JADE, SPADE, AWS SimSpace Weaver).
# - **Integración con sensores IoT, sistemas ERP y fuentes externas** (APIs de clima, tráfico, etc).
# - **Módulos de machine learning** para predicción y simulación.
# - **Interfaces de usuario para monitoreo y override humano en casos críticos.**
#
# ---
#
# ## Conclusión
#
# La **IA basada en agentes** transforma la logística en una red dinámica y resiliente. Cada entidad actúa y coopera como un “organismo vivo”, permitiendo decisiones rápidas, inteligentes y escalables ante las inevitables disrupciones de la cadena de suministro, todo mientras reduce costos y mejora la experiencia del cliente.
#
# ---
#
# ¿Te gustaría que detallemos **un algoritmo específico** de colaboración multi-agente? ¿O prefieres explorar cómo iniciar un **prototipo mínimo viable (MVP)** para vender la idea dentro de tu organización?
#
# Si quieres **otras industrias** o más aplicaciones específicas, dime tus intereses y te armo una guía personalizada.
